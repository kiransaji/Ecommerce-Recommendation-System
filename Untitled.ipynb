# %%
# %run data_processing.py
# Out:
# 2025-08-16 15:47:22.807 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#    ---------------------------------------- 0.0/884.3 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/884.3 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 884.3/884.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/786.8 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/786.8 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 786.8/786.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.2 MB 2.8 MB/s eta 0:00:07
# ...
